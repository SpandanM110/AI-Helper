# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install gradientai --upgrade
# Out:
# ...
#   Obtaining dependency information for gradientai from https://files.pythonhosted.org/packages/f8/db/9587f4993392dbd2b677c3c8559c5157286b47c3fc75efc764c777208ad1/gradientai-1.8.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for aenum>=3.1.11 from https://files.pythonhosted.org/packages/d0/fa/ca0c66b388624ba9dbbf35aab3a9f326bfdf5e56a7237fe8f1b600da6864/aenum-3.1.15-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pydantic<2.0.0,>=1.10.5 from https://files.pythonhosted.org/packages/18/9c/c84ead4e65e85dbb3b9806e8390db91b82993f5248fdfe9dacdd4da9c726/pydantic-1.10.14-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/151.6 kB ? eta -:--:--
#      --------- --------------------------- 41.0/151.6 kB 991.0 kB/s eta 0:00:01
#      ----------------------- --------------- 92.2/151.6 kB 1.1 MB/s eta 0:00:01
#      ------------------------------ ------- 122.9/151.6 kB 1.0 MB/s eta 0:00:01
# ...

# %%
import os
os.environ['GRADIENT_WORKSPACE_ID']='0e1f14df-7e68-49f0-b47e-e96dd82c6053_workspace'
os.environ['GRADIENT_ACCESS_TOKEN']='ESZZUzC3E8ibPHb2WAKMN84AjJYp1tuz'

# %% [markdown]
# GRADIENT APPROACH IF FINE TUNED THEN CAN BE SCALED

# %%
import pyttsx3
import speech_recognition as sr
import datetime  # Add this import statement for the datetime module

# Initialize the text-to-speech engine
engine = pyttsx3.init()

def get_gpt3_response(prompt):
    samples = [
        {"inputs": f"### Instruction: {prompt}\n\n### Response: As per your query, we recommend focusing more on those topics and practicing regularly to improve your understanding and performance."},
    ]
    new_model_adapter.fine_tune(samples=samples)

    completion = new_model_adapter.complete(query=prompt, max_generated_token_count=150).generated_output
    return completion.strip()

def chat_with_gpt3(prompt):
    return get_gpt3_response(prompt)

def takecommand(name):
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print(f"{name}: Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print(f"{name}: Recognizing...")
        query = r.recognize_google(audio, language="en-in")
        print(query)

    except Exception as e:
        print(e)
        speak("Please say that again")
        return "Try Again"

    return query

def wishme(name):
    print("Welcome back sir!!")
    speak("Welcome back sir!!")

    hour = datetime.datetime.now().hour
    if hour >= 4 and hour < 12:
        speak(f"Good Morning {name}!!")
        print(f"Good Morning {name}!!")
    elif hour >= 12 and hour < 16:
        speak(f"Good Afternoon {name}!!")
        print(f"Good Afternoon {name}!!")
    elif hour >= 16 and hour < 24:
        speak(f"Good Evening {name}!!")
        print(f"Good Evening {name}!!")
    else:
        speak(f"Good Night {name}, See You Tomorrow")

    speak(f"{name} at your service sir, please tell me how may I help you.")
    print(f"{name} at your service sir, please tell me how may I help you.")

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def main():
    name = "your_name"  # Replace with your bot's name
    wishme(name)

    while True:
        query = takecommand(name).lower()

        if name.lower() in query:
            query = query.replace(name.lower(), "")

            if "time" in query:
                time()

            elif "date" in query:
                date()

            elif "who are you" in query:
                response = chat_with_gpt3("Who are you?")
                speak(response)
                print(response)

            elif "fine" in query or "good" in query:
                speak("Glad to hear that sir!!")
                print("Glad to hear that sir!!")

            elif "wikipedia" in query:
                try:
                    speak("Ok wait sir, I'm searching...")
                    query = query.replace("wikipedia","")
                    response = chat_with_gpt3(f"What is {query}?")
                    speak(response)
                    print(response)
                except:
                    speak("Can't find this page sir, please ask something else")

if __name__ == "__main__":
    main()

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import openai
import pyttsx3
import pywin32_system32
import datetime
import speech_recognition as sr
import wikipedia
import webbrowser as wb
import os
import random
import pyautogui
import requests
import threading  # Import the OpenAI library

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Initialize the OpenAI API key
openai.api_key = "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"  # Replace "YOUR_OPENAI_API_KEY" with your actual OpenAI API key

def get_gpt3_response(prompt):
    response = openai.Completion.create(
      engine="text-davinci-002",
      prompt=prompt,
      max_tokens=150
    )
    return response.choices[0].text.strip()

def chat_with_gpt3(prompt):
    return get_gpt3_response(prompt)

def takecommand(name):
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print(f"{name}: Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print(f"{name}: Recognizing...")
        query = r.recognize_google(audio, language="en-in")
        print(query)

    except Exception as e:
        print(e)
        speak("Please say that again")
        return "Try Again"

    return query

def wishme(name):
    print("Welcome back sir!!")
    speak("Welcome back sir!!")

    hour = datetime.datetime.now().hour
    if hour >= 4 and hour < 12:
        speak(f"Good Morning {name}!!")
        print(f"Good Morning {name}!!")
    elif hour >= 12 and hour < 16:
        speak(f"Good Afternoon {name}!!")
        print(f"Good Afternoon {name}!!")
    elif hour >= 16 and hour < 24:
        speak(f"Good Evening {name}!!")
        print(f"Good Evening {name}!!")
    else:
        speak(f"Good Night {name}, See You Tomorrow")

    speak("at your service sir, please tell me how may I help you.")
    print("at your service sir, please tell me how may I help you.")

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def main():
    name = "Spandan"  # Replace with your bot's name
    wishme(name)

    while True:
        query = takecommand(name).lower()

        if name.lower() in query:
            query = query.replace(name.lower(), "")

            if "time" in query:
                time()

            elif "date" in query:
                date()

            elif "who are you" in query:
                response = chat_with_gpt3("Who are you?")
                speak(response)
                print(response)

            elif "fine" in query or "good" in query:
                speak("Glad to hear that sir!!")
                print("Glad to hear that sir!!")

            elif "wikipedia" in query:
                try:
                    speak("Ok wait sir, I'm searching...")
                    query = query.replace("wikipedia","")
                    response = chat_with_gpt3(f"What is {query}?")
                    speak(response)
                    print(response)
                except:
                    speak("Can't find this page sir, please ask something else")

            else:
                # If the query doesn't match any predefined commands, fetch response from GPT-3
                response = chat_with_gpt3(query)
                speak(response)
                print(response)

if __name__ == "__main__":
    main()

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import openai

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Initialize the OpenAI API key
openai.api_key = "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"  # Replace "YOUR_OPENAI_API_KEY" with your actual OpenAI API key

def get_gpt3_response(prompt):
    response = openai.Completion.create(
        model="text-davinci-002",
        prompt=prompt,
        max_tokens=150
    )
    return response.choices[0].text.strip()


def chat_with_gpt3(prompt):
    return get_gpt3_response(prompt)

def takecommand(name):
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print(f"{name}: Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print(f"{name}: Recognizing...")
        query = r.recognize_google(audio, language="en-in")
        print(query)

    except Exception as e:
        print(e)
        speak("Please say that again")
        return "Try Again"

    return query

def wishme(name):
    print("Welcome back sir!!")
    speak("Welcome back sir!!")

    hour = datetime.datetime.now().hour
    if hour >= 4 and hour < 12:
        speak(f"Good Morning {name}!!")
        print(f"Good Morning {name}!!")
    elif hour >= 12 and hour < 16:
        speak(f"Good Afternoon {name}!!")
        print(f"Good Afternoon {name}!!")
    elif hour >= 16 and hour < 24:
        speak(f"Good Evening {name}!!")
        print(f"Good Evening {name}!!")
    else:
        speak(f"Good Night {name}, See You Tomorrow")

    speak("At your service sir, please tell me how may I help you.")
    print("At your service sir, please tell me how may I help you.")

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def main():
    name = "Buddybot"  # Replace with your bot's name
    wishme(name)

    while True:
        speak("Please say something to start the conversation.")
        query = takecommand(name).lower()

        response = chat_with_gpt3(query)
        speak(response)
        print(response)

        while True:
            speak("Would you like to continue the conversation? Say 'yes' or 'no'.")
            user_response = takecommand(name).lower()

            if "yes" in user_response:
                speak("Please say something.")
                query = takecommand(name).lower()
                response = chat_with_gpt3(query)
                speak(response)
                print(response)
            elif "no" in user_response:
                speak("Okay, goodbye!")
                print("Okay, goodbye!")
                break
            else:
                speak("Sorry, I didn't understand that. Please say 'yes' or 'no'.")

if __name__ == "__main__":
    main()
# Out:
# Welcome back sir!!
# Good Evening Buddybot!!
# At your service sir, please tell me how may I help you.
# Buddybot: Listening...
# Buddybot: Recognizing...
# what is the capital of India
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[6], line 97
#      94                 speak("Sorry, I didn't understand that. Please say 'yes' or 'no'.")
#      96 if __name__ == "__main__":
# ---> 97     main()
#
# Cell In[6], line 75, in main()
#      72 speak("Please say something to start the conversation.")
#      73 query = takecommand(name).lower()
# ---> 75 response = chat_with_gpt3(query)
#      76 speak(response)
#      77 print(response)
#
# Cell In[6], line 22, in chat_with_gpt3(prompt)
#      21 def chat_with_gpt3(prompt):
# ---> 22     return get_gpt3_response(prompt)
#
# Cell In[6], line 13, in get_gpt3_response(prompt)
#      12 def get_gpt3_response(prompt):
# ...
